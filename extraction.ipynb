# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp "/content/drive/MyDrive/TCSion/words.zip" "words.zip"
# !cp "/content/drive/MyDrive/TCSion/words.txt"
# !unzip 'words.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: words/a01-020-04-04.png
#  extracting: words/d07-085-01-00.png
#  extracting: words/k02-023-00-05.png
#  extracting: words/b06-019-05-04.png
#  extracting: words/g06-047p-05-05.png
#  extracting: words/g01-074-07-02.png
#  extracting: words/g06-011b-06-02.png
#  extracting: words/g04-095-03-01.png
#  extracting: words/r02-054-01-03.png
#  extracting: words/j01-045-09-04.png
#  extracting: words/a01-113u-09-04.png
#  extracting: words/b03-098-05-02.png
#  extracting: words/b01-049-01-04.png
#  extracting: words/d04-066-00-07.png
#  extracting: words/p03-047-00-09.png
#  extracting: words/h02-008-05-03.png
#  extracting: words/b02-013-05-06.png
#  extracting: words/k02-117-06-00.png
#  extracting: words/d01-104-01-03.png
#  extracting: words/d07-089-06-06.png
#  extracting: words/c03-007a-03-02.png
#  extracting: words/a02-037-08-07.png
#  extracting: words/p02-139-02-05.png
#  extracting: words/f02-076-05-05.png
#  extracting: words/l04-093-04-05.png
#  extracting: words/d04-016-07-05.png
#  extracting: words/p02-109-06-01.png
#  extracting: words/m02-112-02-03.png
#  extracting: words/g06-047j-03-05.png
#  extracting: words/g06-042a-00-01.png
#  extracting: words/g04-003-06-03.png
#  extracting: words/m04-038-00-12.png
#  extracting: words/p02-076-02-08.png
#  extracting: words/d06-060-05-04.png
#  extracting: words/g06-047j-00-02.png
#  extracting: words/g06-011f-04-07.png
#  extracting: words/d05-008-05-01.png
#  extracting: words/e07-090-00-05.png
#  extracting: words/g06-031r-05-03.png
#  extracting: words/d01-104-06-08.png
#  extracting: words/d01-104-00-02.png
#  extracting: words/m04-231-01-03.png
#  extracting: words/b06-082-07-04.png
#  extracting: words/a06-110-02-00.png
#  extracting: words/l04-043-06-05.png
#  extracting: words/r06-062-00-01.png
#  extracting: words/f04-053-06-04.png
#  extracting: words/g06-045i-05-04.png
#  extracting: words/m02-083-00-07.png
#  extracting: words/r03-110-01-06.png
#  extracting: words/m04-000-05-03.png
#  extracting: words/p02-000-00-05.png
#  extracting: words/l07-074-01-01.png
#  extracting: words/c06-111-00-06.png
#  extracting: words/m06-083-03-02.png
#  extracting: words/r06-007-02-08.png
#  extracting: words/g06-050e-04-07.png
#  extracting: words/e02-021-06-07.png
#  extracting: words/j04-070-04-04.png
#  extracting: words/n06-119-05-09.png
#  extracting: words/l04-118-02-08.png
#  extracting: words/c06-111-01-07.png
#  extracting: words/h06-089-10-03.png
#  extracting: words/b04-175-03-01.png
#  extracting: words/j06-008-03-01.png
#  extracting: words/g02-059-00-04.png
#  extracting: words/r03-050-06-00.png
#  extracting: words/j07-000-03-06.png
#  extracting: words/p02-135-05-03.png
#  extracting: words/k04-000-04-08.png
#  extracting: words/a01-026-09-01.png
#  extracting: words/m01-125-03-01.png
#  extracting: words/k04-010-07-06.png
#  extracting: words/g04-068-07-00.png
#  extracting: words/a01-049u-02-05.png
#  extracting: words/a01-117u-00-05.png
#  extracting: words/c03-016e-00-05.png
#  extracting: words/g04-104-03-03.png
#  extracting: words/m04-180-01-09.png
#  extracting: words/j04-061-01-03.png
#  extracting: words/g06-037o-01-01.png
#  extracting: words/f07-073-08-08.png
#  extracting: words/e06-033-01-05.png
#  extracting: words/d04-121-00-01.png
#  extracting: words/g06-050k-07-06.png
#  extracting: words/g06-011g-06-01.png
#  extracting: words/d06-107-07-00.png
#  extracting: words/b06-087-05-00.png
#  extracting: words/m01-125-07-03.png
#  extracting: words/g06-042a-01-03.png
#  extracting: words/c06-047-06-04.png
#  extracting: words/a06-051-00-08.png
#  extracting: words/f04-064-07-04.png
#  extracting: words/m04-164-04-08.png
#  extracting: words/h04-049-03-00.png
#  extracting: words/p03-096-04-01.png
#  extracting: words/g06-018p-02-02.png
#  extracting: words/p03-040-04-03.png
#  extracting: words/m03-062-02-05.png
#  extracting: words/l04-071-03-06.png
#  extracting: words/p03-158-07-00.png
#  extracting: words/b01-136-02-06.png
#  extracting: words/e04-034-06-01.png
#  extracting: words/a05-009-06-04.png
#  extracting: words/h05-012-01-02.png
#  extracting: words/l04-106-03-04.png
#  extracting: words/e02-018-01-01.png
#  extracting: words/j06-000-01-04.png
#  extracting: words/g06-105-03-04.png
#  extracting: words/g06-026a-01-04.png
#  extracting: words/g07-042-02-00.png
#  extracting: words/g06-026h-00-10.png
#  extracting: words/l01-030-00-04.png
#  extracting: words/l01-111-02-07.png
#  extracting: words/g07-007a-10-07.png
#  extracting: words/a01-053x-08-01.png
#  extracting: words/c02-007-05-07.png
#  extracting: words/m04-190-03-08.png
#  extracting: words/a02-046-07-03.png
#  extracting: words/g07-003b-01-04.png
#  extracting: words/g06-011a-06-00.png
#  extracting: words/c06-011-00-02.png
#  extracting: words/a04-039-07-03.png
#  extracting: words/a06-020-04-09.png
#  extracting: words/r06-090-01-01.png
#  extracting: words/m04-007-04-09.png
#  extracting: words/a01-020-03-07.png
#  extracting: words/e06-021-06-04.png
#  extracting: words/f04-074-09-02.png
#  extracting: words/d07-082-03-06.png
#  extracting: words/d06-046-08-02.png
#  extracting: words/n06-163-00-05.png
#  extracting: words/c03-081c-01-05.png
#  extracting: words/a01-053-10-04.png
#  extracting: words/g01-025-03-00.png
#  extracting: words/m04-209-06-04.png
#  extracting: words/c06-047-06-00.png
#  extracting: words/m01-079-02-09.png
#  extracting: words/k04-093-07-01.png
#   inflating: words/m04-138-07-00.png
#  extracting: words/r06-106-03-05.png
#  extracting: words/n04-048-02-01.png
#  extracting: words/a02-008-04-01.png
#  extracting: words/k04-050-04-10.png
#  extracting: words/r06-007-04-00.png
#  extracting: words/g06-047i-04-09.png
#  extracting: words/e04-038-00-05.png
#  extracting: words/j06-056-06-02.png
#  extracting: words/p02-069-08-00.png
#  extracting: words/c03-096f-03-02.png
#  extracting: words/f07-081a-06-06.png
#  extracting: words/g06-093-07-00.png
#  extracting: words/g06-037r-01-04.png
#  extracting: words/p02-105-07-05.png
#  extracting: words/g04-007-00-06.png
#  extracting: words/h07-013-07-06.png
#  extracting: words/g06-037h-04-07.png
#  extracting: words/g05-094-07-06.png
#  extracting: words/d04-089-05-00.png
#  extracting: words/g06-031m-02-05.png
#  extracting: words/p02-090-01-00.png
#  extracting: words/h02-022-03-04.png
#  extracting: words/m06-019-01-07.png
#  extracting: words/g07-022a-03-04.png
#  extracting: words/r06-053-01-02.png
#  extracting: words/a01-014-05-01.png
#  extracting: words/m02-075-02-02.png
#  extracting: words/a05-089-09-00.png
#  extracting: words/n02-062-05-10.png
#  extracting: words/a06-152-06-00.png
#  extracting: words/g06-037l-03-09.png
#  extracting: words/g06-018i-05-09.png
#  extracting: words/a01-053u-05-06.png
#  extracting: words/g06-037p-06-04.png
#  extracting: words/c06-106-01-05.png
#  extracting: words/m04-251-01-06.png
#  extracting: words/c03-007f-03-06.png
#  extracting: words/f02-003-01-04.png
#  extracting: words/a04-066-02-00.png
#  extracting: words/p03-069-02-10.png
#  extracting: words/g03-016-03-07.png
#  extracting: words/g07-003b-08-00.png
#  extracting: words/g06-011a-08-07.png
#  extracting: words/c03-087d-06-06.png
#  extracting: words/h04-021-00-07.png
#  extracting: words/n01-057-00-02.png
#  extracting: words/g06-031a-06-10.png
#  extracting: words/l07-172-01-01.png
#  extracting: words/b01-094-01-02.png
#  extracting: words/b01-014-03-01.png
#  extracting: words/a02-017-01-04.png
#  extracting: words/f07-046a-05-07.png
#  extracting: words/r06-027-03-07.png
#  extracting: words/d06-046-05-03.png
#  extracting: words/a04-006-07-05.png
#  extracting: words/d06-072-01-05.png
#  extracting: words/r03-084-07-02.png
#  extracting: words/c04-144-03-05.png
#  extracting: words/d06-100-06-04.png
#  extracting: words/e01-035-06-07.png
#  extracting: words/e07-086-02-02.png
#  extracting: words/g03-058-00-02.png
#  extracting: words/r02-127-01-10.png
#  extracting: words/l07-172-10-02.png
#  extracting: words/d06-027-04-07.png
#  extracting: words/e07-076-02-05.png
#  extracting: words/n03-091-00-04.png
#  extracting: words/a05-094-01-05.png
#  extracting: words/e01-055-03-02.png
#  extracting: words/g06-050o-02-01.png
#  extracting: words/n03-120-09-01.png
#  extracting: words/p01-147-03-02.png
#  extracting: words/l07-131-07-05.png
#  extracting: words/m01-160-04-03.png
#  extracting: words/e01-032-07-00.png
#  extracting: words/g06-105-03-00.png
#  extracting: words/b05-062-02-07.png
#  extracting: words/b05-067-00-00.png
#  extracting: words/a01-003x-04-08.png
#  extracting: words/c02-082-05-00.png
#  extracting: words/p02-081-01-02.png
#  extracting: words/b03-025-03-05.png
#  extracting: words/n06-128-06-07.png
#  extracting: words/g06-026c-03-08.png
#  extracting: words/k04-061-07-07.png
#  extracting: words/k04-050-03-05.png
#  extracting: words/r06-090-08-01.png
#  extracting: words/a01-128u-08-03.png
#  extracting: words/e04-011-08-00.png
#  extracting: words/l04-071-00-08.png
#  extracting: words/l01-129-05-05.png
#  extracting: words/g06-037c-00-08.png
#  extracting: words/d04-005-00-00.png
#  extracting: words/e02-014-05-07.png
#  extracting: words/f02-036-05-03.png
#  extracting: words/g07-003b-03-02.png
#  extracting: words/e07-105-03-02.png
#  extracting: words/k04-022-01-07.png
#  extracting: words/c04-056-03-03.png
#  extracting: words/e07-061-02-06.png
#  extracting: words/e04-038-00-04.png
#  extracting: words/b01-018-08-00.png
#  extracting: words/g06-018k-05-07.png
#  extracting: words/e02-000-03-07.png
#  extracting: words/l01-119-00-12.png
#  extracting: words/g01-027-04-04.png
#  extracting: words/a01-113u-05-02.png
#  extracting: words/n06-148-00-03.png
#  extracting: words/g07-069a-04-03.png
#  extracting: words/l04-179-05-02.png
#  extracting: words/h05-012-02-00.png
#  extracting: words/h04-061-06-03.png
#  extracting: words/c03-016d-05-01.png
#  extracting: words/n03-113-08-01.png
#  extracting: words/e01-081-00-04.png
#  extracting: words/r06-121-09-03.png
#  extracting: words/g06-031i-05-09.png
#  extracting: words/r06-115-01-05.png
#  extracting: words/d04-016-07-01.png
#  extracting: words/n02-127-00-05.png
#  extracting: words/r02-109-00-02.png
#  extracting: words/g06-047f-01-06.png
#  extracting: words/a02-078-00-03.png
#  extracting: words/c06-031-06-01.png
#  extracting: words/f07-032a-09-00.png
#  extracting: words/j06-005-01-02.png
#  extracting: words/l04-113-05-06.png
#  extracting: words/p03-163-05-07.png
#  extracting: words/g06-047r-02-07.png
#  extracting: words/a05-121-07-03.png
#  extracting: words/a03-034-07-00.png
#  extracting: words/d06-111-04-06.png
#  extracting: words/a06-020-04-07.png
#  extracting: words/p06-096-08-05.png
#  extracting: words/l07-187-07-06.png
#  extracting: words/k03-144-04-10.png
#  extracting: words/h06-000-06-01.png
#  extracting: words/g06-042k-00-03.png
#  extracting: words/b03-109-07-03.png
#  extracting: words/g06-011j-07-01.png
#  extracting: words/a01-030-04-06.png
#  extracting: words/a03-014-05-00.png
#  extracting: words/a01-117u-03-06.png
#  extracting: words/a01-020x-02-07.png
#  extracting: words/c02-089-00-03.png
#  extracting: words/k04-033-07-05.png
#  extracting: words/f03-182-02-09.png
#  extracting: words/g06-037k-07-06.png
#  extracting: words/m02-055-04-07.png
#  extracting: words/b04-140-07-00.png
#  extracting: words/g04-052-04-02.png
#  extracting: words/r03-053-00-00.png
#  extracting: words/a05-069-00-06.png
#  extracting: words/b04-060-03-02.png
#  extracting: words/p03-023-03-05.png
#  extracting: words/a01-091u-03-05.png
#  extracting: words/d01-049-06-01.png
#  extracting: words/m04-030-03-10.png
#  extracting: words/e01-119-02-04.png
#  extracting: words/a01-020-07-02.png
#  extracting: words/n02-045-06-01.png
#  extracting: words/m01-084-06-04.png
#  extracting: words/e07-072-11-03.png
#  extracting: words/g06-018g-04-06.png
#  extracting: words/c03-094f-08-02.png
#  extracting: words/c04-004-04-03.png
#  extracting: words/b04-040-04-06.png
#  extracting: words/c02-056-08-00.png
#  extracting: words/f01-135-09-03.png
#  extracting: words/n02-114-06-09.png
#  extracting: words/n04-015-06-02.png
#  extracting: words/c03-003d-01-00.png
#  extracting: words/e04-008-01-10.png
#  extracting: words/a03-020-03-02.png
#  extracting: words/l04-005-05-00.png
#  extracting: words/c06-043-00-00.png
#  extracting: words/j06-018-07-06.png
#  extracting: words/p06-088-05-04.png
#  extracting: words/a01-011x-08-00.png
#  extracting: words/p03-112-02-05.png
#  extracting: words/e06-010-04-03.png
#  extracting: words/d04-101-01-09.png
#  extracting: words/n02-009-03-08.png
#  extracting: words/a01-122-05-04.png
#  extracting: words/k04-061-03-03.png
#  extracting: words/b02-045-05-10.png
#  extracting: words/n02-033-08-00.png
#  extracting: words/g06-018n-05-04.png
#  extracting: words/g06-047b-06-02.png
#  extracting: words/f07-073-09-05.png
#  extracting: words/j01-049-03-05.png
#  extracting: words/g06-045i-01-06.png
#  extracting: words/g06-026r-02-10.png
#  extracting: words/a04-000-04-00.png
#  extracting: words/d06-104-06-02.png
#  extracting: words/h06-000-07-02.png
#  extracting: words/b04-047-03-11.png
#  extracting: words/g06-115-02-00.png
#  extracting: words/a01-049x-01-02.png
#  extracting: words/m02-080-03-07.png
#  extracting: words/a04-050-03-06.png
#  extracting: words/h07-025a-03-02.png
#  extracting: words/g05-098-03-06.png
#  extracting: words/k07-122-01-01.png
#  extracting: words/c03-007a-07-02.png
#  extracting: words/c03-021d-03-01.png
#  extracting: words/g01-034-05-03.png
#  extracting: words/l01-016-05-06.png
#  extracting: words/h07-080-04-05.png
#  extracting: words/g06-031d-05-06.png
#  extracting: words/m01-115-02-00.png
#  extracting: words/g04-048-05-09.png
#  extracting: words/e07-090-00-06.png
#  extracting: words/g06-050i-06-05.png
#  extracting: words/b04-202-04-00.png
#  extracting: words/f02-003-04-03.png
#  extracting: words/r02-065-03-07.png
#  extracting: words/e01-055-04-02.png
#  extracting: words/m02-069-07-09.png
#  extracting: words/p03-135-03-09.png
#  extracting: words/g07-026a-09-03.png
#  extracting: words/g06-031n-02-05.png
#  extracting: words/a03-034-04-04.png
#  extracting: words/g02-059-07-01.png
#  extracting: words/l04-034-01-05.png
#  extracting: words/b04-010-07-01.png
#  extracting: words/g01-019-06-03.png
#  extracting: words/l04-093-00-03.png
#  extracting: words/n04-039-03-09.png
#  extracting: words/l04-159-00-00.png
#  extracting: words/e04-099-02-09.png
#  extracting: words/f01-147-03-06.png
#  extracting: words/b06-075-01-05.png
#  extracting: words/a05-022-01-00.png
#  extracting: words/p02-017-03-07.png
#  extracting: words/p06-047-07-00.png
#  extracting: words/e04-132-00-07.png
#  extracting: words/c04-098-01-09.png
#  extracting: words/h04-025-01-10.png
#  extracting: words/g04-017-00-08.png
#  extracting: words/m03-095-03-00.png
#  extracting: words/r06-130-09-06.png
#  extracting: words/n06-123-04-06.png
#  extracting: words/r02-070-05-09.png
#  extracting: words/g04-014-04-04.png
#  extracting: words/n02-157-01-03.png
#  extracting: words/b03-092-03-08.png
#  extracting: words/c03-007b-02-01.png
#  extracting: words/c03-081b-03-05.png
#  extracting: words/g06-047g-05-05.png
#  extracting: words/a05-104-06-01.png
#  extracting: words/a01-091-09-06.png
#  extracting: words/g06-045p-03-08.png
#  extracting: words/r06-137-01-02.png
#  extracting: words/a05-025-01-01.png
#  extracting: words/c06-116-06-03.png
#  extracting: words/j04-065-01-06.png
#  extracting: words/g07-084-05-08.png
#  extracting: words/b04-054-00-01.png
#  extracting: words/a01-053x-06-04.png
#  extracting: words/j04-012-04-04.png
#  extracting: words/f07-024b-02-00.png
#  extracting: words/g07-022a-07-08.png
#  extracting: words/g01-008-06-04.png
#  extracting: words/n03-091-04-05.png
#  extracting: words/d04-021-00-01.png
#  extracting: words/d01-060-05-08.png
#  extracting: words/h07-060b-03-08.png
#  extracting: words/e04-052-06-05.png
#  extracting: words/k02-062-02-03.png
#  extracting: words/a05-029-02-03.png
#  extracting: words/g06-018m-03-10.png
#  extracting: words/g06-018h-00-04.png
#  extracting: words/n03-120-06-02.png
#  extracting: words/a03-014-06-02.png
#  extracting: words/a06-000-06-04.png
#  extracting: words/d06-041-02-07.png
#  extracting: words/n04-156-04-03.png
#  extracting: words/k02-018-02-08.png
#  extracting: words/e04-079-07-01.png
#  extracting: words/n06-201-07-02.png
#  extracting: words/m01-017-04-08.png
#  extracting: words/m02-069-04-02.png
#  extracting: words/k02-067-02-02.png
#  extracting: words/a04-069-05-02.png
#  extracting: words/n04-039-04-07.png
#  extracting: words/a01-030u-05-06.png
#  extracting: words/c02-078-02-01.png
#  extracting: words/h01-004-03-05.png
#  extracting: words/c03-084e-02-00.png
#  extracting: words/h07-044a-03-04.png
#  extracting: words/g01-004-05-01.png
#  extracting: words/g04-077-05-00.png
#  extracting: words/b01-079-07-04.png
#  extracting: words/f07-019b-04-06.png
#  extracting: words/c06-087-02-10.png
#  extracting: words/g06-045r-05-00.png
#  extracting: words/m02-048-04-06.png
#  extracting: words/h07-037a-06-01.png
#  extracting: words/k03-144-01-00.png
#  extracting: words/a01-003-06-05.png
#  extracting: words/m06-019-05-09.png
#  extracting: words/e07-086-09-00.png
#  extracting: words/m01-100-03-07.png
#  extracting: words/h06-079-00-00.png
#  extracting: words/b05-042-04-01.png
#  extracting: words/f07-019a-01-04.png
#  extracting: words/m04-024-06-03.png
#  extracting: words/a06-057-05-06.png
#  extracting: words/n06-156-02-05.png
#  extracting: words/f01-147-02-06.png
#  extracting: words/k02-097-03-04.png
#  extracting: words/g01-088-07-01.png
#  extracting: words/b01-009-06-00.png
#  extracting: words/e07-112-04-02.png
#  extracting: words/g06-045l-01-06.png
#  extracting: words/a05-062-08-04.png
#  extracting: words/c03-021e-06-08.png
#  extracting: words/g01-012-03-06.png
#  extracting: words/k07-059a-01-05.png
#  extracting: words/m03-062-02-06.png
#  extracting: words/r06-018-03-06.png
#  extracting: words/d07-096-08-03.png
#  extracting: words/k03-138-02-12.png
#  extracting: words/b04-060-00-03.png
#  extracting: words/g06-018e-01-02.png
#  extracting: words/g06-050g-02-00.png
#  extracting: words/c04-017-06-02.png
#  extracting: words/f04-016-00-00.png
#  extracting: words/n02-004-01-00.png
#  extracting: words/b04-004-08-01.png
#  extracting: words/l04-098-01-04.png
#  extracting: words/g06-037d-03-08.png
#  extracting: words/f02-030-05-04.png
#  extracting: words/g06-031n-04-00.png
#  extracting: words/m04-145-02-01.png
#  extracting: words/d06-008-08-03.png
#  extracting: words/m02-075-01-02.png
#  extracting: words/g06-011o-10-04.png
#  extracting: words/g07-044-09-10.png
#  extracting: words/p02-150-06-08.png
#  extracting: words/n06-186-01-06.png
#  extracting: words/c04-004-00-07.png
#  extracting: words/c03-081a-07-09.png
#  extracting: words/a02-090-04-01.png
#  extracting: words/f07-000b-03-05.png
#  extracting: words/a04-103-00-01.png
#  extracting: words/r06-106-07-00.png
#  extracting: words/a04-003-04-00.png
#  extracting: words/g06-018e-01-10.png
#  extracting: words/n04-130-01-06.png
#  extracting: words/b03-098-01-03.png
#  extracting: words/p03-004-01-00.png
#  extracting: words/b01-118-04-00.png
#  extracting: words/k07-063a-06-01.png
#  extracting: words/g06-026e-03-08.png
#  extracting: words/h07-063a-05-10.png
#  extracting: words/l04-141-03-12.png
#  extracting: words/d04-005-06-03.png
#  extracting: words/m01-017-03-04.png
#  extracting: words/h02-028-08-04.png
#  extracting: words/h07-030-06-05.png
#  extracting: words/m06-106-02-06.png
#  extracting: words/a05-094-06-02.png
#  extracting: words/m04-019-02-09.png
#  extracting: words/g07-050-03-08.png
#  extracting: words/f07-019a-01-05.png
#  extracting: words/r03-090-05-02.png
#  extracting: words/d06-076-03-07.png
#  extracting: words/b03-092-01-10.png
#  extracting: words/p02-139-03-14.png
#  extracting: words/c02-082-06-00.png
#  extracting: words/n02-062-01-03.png
#  extracting: words/n04-015-04-10.png
#  extracting: words/c01-014-05-01.png
#  extracting: words/g06-047m-02-07.png
#  extracting: words/g07-028b-06-00.png
#  extracting: words/d06-076-04-07.png
#  extracting: words/r06-007-02-03.png
#  extracting: words/c03-087d-05-07.png
#  extracting: words/g06-045d-01-06.png
#  extracting: words/n03-082-06-03.png
#  extracting: words/g06-042k-02-06.png
#  extracting: words/g06-011m-06-00.png
#  extracting: words/g06-042p-00-00.png
#  extracting: words/l07-187-05-01.png
#  extracting: words/r06-121-08-05.png
#  extracting: words/e07-007-02-06.png
#  extracting: words/g06-026b-02-04.png
#  extracting: words/c06-011-02-01.png
#  extracting: words/c04-028-05-00.png
#  extracting: words/g06-026d-02-00.png
#  extracting: words/g06-026e-00-06.png
#  extracting: words/g07-007a-06-05.png
#  extracting: words/b04-047-01-00.png
#  extracting: words/d01-098-04-00.png
#  extracting: words/m04-138-06-02.png
#  extracting: words/e04-099-03-07.png
#  extracting: words/p06-047-09-03.png
#  extracting: words/g06-018k-03-02.png
#  extracting: words/j04-035-00-05.png
#  extracting: words/n01-004-01-01.png
#  extracting: words/c04-110-01-07.png
#  extracting: words/g03-043-03-07.png
#  extracting: words/b04-128-05-02.png
#  extracting: words/r02-117-06-05.png
#  extracting: words/c06-100-04-00.png
#  extracting: words/g01-083-01-06.png
#  extracting: words/a01-030u-08-03.png
#  extracting: words/e04-099-02-07.png
#  extracting: words/h04-021-01-09.png
#  extracting: words/f07-042a-02-07.png
#  extracting: words/c03-096a-03-06.png
#  extracting: words/f07-096-05-07.png
#  extracting: words/b04-103-02-02.png
#  extracting: words/h02-024-00-03.png
#  extracting: words/g06-026d-04-07.png
#  extracting: words/a06-039-00-06.png
#  extracting: words/g07-007b-04-04.png
#  extracting: words/g06-031p-06-06.png
#  extracting: words/b05-083-04-02.png
#  extracting: words/a01-020-03-06.png
#  extracting: words/h07-020-08-02.png
#  extracting: words/h05-012-00-04.png
#  extracting: words/b05-045-01-04.png
#  extracting: words/l01-199-05-04.png
#  extracting: words/c01-014-04-06.png
#  extracting: words/c04-170-03-05.png
#  extracting: words/a04-031-01-05.png
#  extracting: words/c04-089-04-09.png
#  extracting: words/g07-000a-00-04.png
#  extracting: words/g02-059-04-02.png
#  extracting: words/h01-007-05-02.png
#  extracting: words/c02-026-03-00.png
#  extracting: words/a03-027-01-09.png
#  extracting: words/b01-049-05-00.png
#  extracting: words/n04-130-04-03.png
#  extracting: words/p02-022-01-08.png
#  extracting: words/g06-026h-02-06.png
#  extracting: words/h04-061-00-02.png
#  extracting: words/g06-011e-07-07.png
#  extracting: words/g06-042p-05-00.png
#  extracting: words/r06-115-03-06.png
#  extracting: words/k07-085-02-02.png
#  extracting: words/j06-056-05-00.png
#  extracting: words/b02-035-03-05.png
#  extracting: words/k01-051-07-06.png
#  extracting: words/a04-027-01-08.png
#  extracting: words/g01-070-01-06.png
#  extracting: words/g07-038-05-05.png
#  extracting: words/m04-222-06-04.png
#  extracting: words/j04-019-09-05.png
#  extracting: words/l07-172-04-01.png
#  extracting: words/r06-130-06-01.png
#  extracting: words/f07-002-03-05.png
#  extracting: words/n06-140-04-09.png
#  extracting: words/j04-046-08-04.png
#  extracting: words/g06-037j-04-02.png
#  extracting: words/n04-068-04-01.png
#  extracting: words/g06-042e-02-05.png
#  extracting: words/n03-126-03-00.png
#  extracting: words/h07-023-02-05.png
#  extracting: words/b04-162-03-07.png
#  extracting: words/g07-007b-03-04.png
#  extracting: words/r06-011-00-01.png
#  extracting: words/a02-111-03-02.png
#  extracting: words/f07-092b-02-03.png
#  extracting: words/b04-020-06-07.png
#  extracting: words/h07-007-01-05.png
#  extracting: words/d04-021-03-03.png
#  extracting: words/b06-042-09-03.png
#  extracting: words/n04-218-06-08.png
#  extracting: words/g06-037k-05-04.png
#  extracting: words/c06-005-07-02.png
#  extracting: words/a01-043-02-02.png
#  extracting: words/g06-037r-09-03.png
#  extracting: words/m02-055-05-00.png
#  extracting: words/n03-079-04-03.png
#  extracting: words/m01-026-07-04.png
#  extracting: words/a02-032-05-05.png
#  extracting: words/m01-160-04-02.png
#  extracting: words/a05-004-02-01.png
#  extracting: words/g04-055-08-07.png
#  extracting: words/g06-011h-00-07.png
#  extracting: words/k02-036-02-07.png
#  extracting: words/g04-068-02-04.png
#  extracting: words/g06-037n-03-05.png
#  extracting: words/g06-031j-01-06.png
#  extracting: words/r06-018-06-03.png
#  extracting: words/b01-118-03-07.png
#  extracting: words/m04-164-03-09.png
#  extracting: words/f02-040-09-08.png
#  extracting: words/h07-075-05-07.png
#  extracting: words/g06-011c-06-11.png
#  extracting: words/e01-022-05-01.png
#  extracting: words/a02-111-02-07.png
#  extracting: words/b06-097-02-08.png
#  extracting: words/a01-053u-05-05.png
#  extracting: words/m06-091-03-00.png
#  extracting: words/a01-102u-07-04.png
#  extracting: words/c03-087b-01-04.png
#  extracting: words/g07-050-01-02.png
#  extracting: words/l04-005-04-02.png
#  extracting: words/k04-075-07-03.png
#  extracting: words/e04-015-03-07.png
#  extracting: words/g04-048-05-07.png
#  extracting: words/e01-107-06-03.png
#  extracting: words/a01-132u-06-02.png
#  extracting: words/a01-000x-03-00.png
#  extracting: words/f01-143-04-00.png
#  extracting: words/d01-118-02-01.png
#  extracting: words/b01-038-04-04.png
#  extracting: words/n06-148-04-00.png
#  extracting: words/k04-075-06-05.png
#  extracting: words/n06-100-04-05.png
#  extracting: words/d06-100-04-06.png
#  extracting: words/l07-111-05-06.png
#  extracting: words/c03-096e-03-02.png
#  extracting: words/a01-132u-00-02.png
#  extracting: words/a01-132u-08-01.png
#  extracting: words/m04-246-06-11.png
#  extracting: words/l01-187-06-05.png
#  extracting: words/d06-086-03-07.png
#  extracting: words/g06-011p-02-03.png
#  extracting: words/a01-072x-00-08.png
#  extracting: words/p03-012-00-05.png
#  extracting: words/c03-007c-07-00.png
#  extracting: words/d04-012-03-03.png
#  extracting: words/a01-003-06-03.png
#  extracting: words/h07-051b-02-08.png
#  extracting: words/c03-081b-03-03.png
#  extracting: words/d06-046-02-04.png
#  extracting: words/n06-133-02-08.png
#  extracting: words/c03-000d-05-00.png
#  extracting: words/l07-111-09-02.png
#  extracting: words/c03-000f-08-00.png
#  extracting: words/b06-064-03-05.png
#  extracting: words/f03-191-06-08.png
#  extracting: words/e04-034-07-03.png
#  extracting: words/c04-139-04-01.png
#  extracting: words/a04-039-02-05.png
#  extracting: words/f01-081-03-08.png
#  extracting: words/a04-031-01-02.png
#  extracting: words/d03-112-05-04.png
#  extracting: words/h01-007-03-02.png
#  extracting: words/b06-012-01-06.png
#  extracting: words/b06-004-01-04.png
#  extracting: words/b04-000-01-03.png
#  extracting: words/g01-012-03-02.png
#  extracting: words/g06-042j-00-07.png
#  extracting: words/k03-144-04-00.png
#  extracting: words/f01-085-05-04.png
#  extracting: words/n06-148-03-08.png
#  extracting: words/a01-014x-00-02.png
#  extracting: words/a06-095-09-03.png
#  extracting: words/r02-013-03-05.png
#  extracting: words/c04-017-02-05.png
#  extracting: words/b01-084-03-02.png
#  extracting: words/g06-042b-00-01.png
#  extracting: words/c06-106-00-03.png
#  extracting: words/f07-002-06-03.png
#  extracting: words/c02-059-01-07.png
#  extracting: words/c02-000-01-04.png
#  extracting: words/k02-112-06-01.png
#  extracting: words/a03-027-07-02.png
#  extracting: words/e06-000-05-04.png
#  extracting: words/a02-053-01-11.png
#  extracting: words/b05-088-06-08.png
#  extracting: words/b05-067-00-05.png
#  extracting: words/k07-125-00-06.png
#  extracting: words/d04-081-00-05.png
#  extracting: words/b06-049-05-03.png
#  extracting: words/g06-026i-00-00.png
#  extracting: words/j04-015-00-06.png
#  extracting: words/b02-045-00-03.png
#  extracting: words/l04-163-05-11.png
#  extracting: words/g06-047h-06-02.png
#  extracting: words/b04-121-01-10.png
#  extracting: words/a01-072u-04-08.png
#  extracting: words/a06-051-07-03.png
#  extracting: words/d06-086-02-04.png
#  extracting: words/a01-011u-01-03.png
#  extracting: words/a01-003u-01-04.png
#  extracting: words/g06-042i-04-01.png
#  extracting: words/j04-015-02-08.png
#  extracting: words/g03-058-04-05.png
#  extracting: words/g06-047d-01-01.png
#  extracting: words/g04-032-01-07.png
#  extracting: words/b02-097-07-04.png
#  extracting: words/n02-146-02-12.png
#  extracting: words/d01-085-03-04.png
#  extracting: words/k02-053-04-05.png
#  extracting: words/g04-048-04-01.png
#  extracting: words/h04-057-06-04.png
#  extracting: words/a03-017-05-05.png
#  extracting: words/b04-081-02-10.png
#  extracting: words/g06-042c-04-04.png
#  extracting: words/j06-008-08-04.png
#  extracting: words/n02-151-06-04.png
#  extracting: words/r02-117-04-06.png
#  extracting: words/g06-109-06-07.png
#  extracting: words/b05-058-01-08.png
#  extracting: words/k04-022-06-06.png
#  extracting: words/a04-085-08-00.png
#  extracting: words/n06-194-01-00.png
#  extracting: words/g06-050h-07-01.png
#  extracting: words/a06-014-03-03.png
#  extracting: words/k04-110-06-06.png
#  extracting: words/j06-000-05-06.png
#  extracting: words/b03-104-03-06.png
#  extracting: words/n03-103-03-05.png
#  extracting: words/a06-152-10-00.png
#  extracting: words/f02-017-00-05.png
#  extracting: words/n02-054-06-08.png
#  extracting: words/h07-023-07-02.png
#  extracting: words/a01-007x-04-02.png
#  extracting: words/k03-164-04-00.png
#  extracting: words/e04-062-07-00.png
#  extracting: words/l01-199-05-00.png
#  extracting: words/c06-031-07-02.png
#  extracting: words/g06-031r-05-09.png
#  extracting: words/r03-050-05-08.png
#  extracting: words/a02-057-03-08.png
#  extracting: words/c03-096e-04-08.png
#  extracting: words/a04-019-06-03.png
#  extracting: words/h07-063b-04-02.png
#  extracting: words/m06-091-00-03.png
#  extracting: words/j04-080-03-01.png
#  extracting: words/b04-010-03-02.png
#  extracting: words/p06-088-08-00.png
#  extracting: words/a04-031-05-04.png
#  extracting: words/g06-047l-02-04.png
#  extracting: words/c04-089-00-02.png
#  extracting: words/a04-019-00-05.png
#  extracting: words/p02-127-03-04.png
#  extracting: words/c03-081a-05-04.png
#  extracting: words/k02-117-00-08.png
#  extracting: words/g06-011j-08-06.png
#  extracting: words/c04-039-01-02.png
#  extracting: words/h07-011-00-07.png
#  extracting: words/n04-084-04-00.png
#  extracting: words/m04-100-02-06.png
#  extracting: words/c02-012-06-06.png
#  extracting: words/g07-079a-10-06.png
#  extracting: words/j06-034-06-01.png
#  extracting: words/a01-087u-01-05.png
#  extracting: words/p02-109-06-03.png
#  extracting: words/d06-027-00-03.png
#  extracting: words/a02-082-04-00.png
#  extracting: words/h07-025a-04-07.png
#  extracting: words/g06-042i-01-08.png
#  extracting: words/d01-098-00-04.png
#  extracting: words/d04-050-02-05.png
#  extracting: words/p02-144-04-08.png
#  extracting: words/h07-000-01-05.png
#  extracting: words/g06-045p-04-01.png
#  extracting: words/g06-042i-02-09.png
#  extracting: words/g06-026e-05-02.png
#  extracting: words/j07-009-02-02.png
#  extracting: words/c03-094d-06-05.png
#  extracting: words/b04-066-03-01.png
#  extracting: words/n02-016-01-03.png
#  extracting: words/b06-110-05-07.png
#  extracting: words/n02-104-01-05.png
#  extracting: words/c03-094b-05-01.png
#  extracting: words/m04-190-00-05.png
#  extracting: words/f03-174-03-04.png
#  extracting: words/c03-003e-01-00.png
#  extracting: words/g06-047f-00-02.png
#  extracting: words/g03-000-01-04.png
#  extracting: words/f07-088a-07-01.png
#  extracting: words/l07-052-02-14.png
#  extracting: words/r02-137-02-04.png
#  extracting: words/g04-077-02-04.png
#  extracting: words/b01-018-06-01.png
#  extracting: words/g07-079a-02-03.png
#  extracting: words/r06-066-03-02.png
#  extracting: words/g06-031p-03-00.png
#  extracting: words/k04-022-07-03.png
#  extracting: words/k03-164-07-05.png
#  extracting: words/p02-127-06-00.png
#  extracting: words/f04-046-02-01.png
#  extracting: words/g06-011b-10-05.png
#  extracting: words/r06-049-10-04.png
#  extracting: words/c04-013-02-03.png
#  extracting: words/l03-004-07-07.png
#  extracting: words/a01-038x-00-05.png
#  extracting: words/e04-015-00-05.png
#  extracting: words/c03-016d-01-07.png
#  extracting: words/j06-022-01-02.png
#  extracting: words/p02-150-07-04.png
#  extracting: words/a01-107-01-09.png
#  extracting: words/p01-168-05-08.png
#  extracting: words/a04-072-05-03.png
#  extracting: words/e01-119-04-03.png
#  extracting: words/c04-044-05-02.png
#  extracting: words/k03-117-03-00.png
#  extracting: words/h02-024-03-06.png
#  extracting: words/f01-058-06-01.png
#  extracting: words/g03-052-07-07.png
#  extracting: words/a04-031-06-04.png
#  extracting: words/d05-021-02-07.png
#  extracting: words/n04-114-05-01.png
#  extracting: words/m04-113-07-03.png
#  extracting: words/h04-074-02-07.png
#  extracting: words/d04-021-00-02.png
#  extracting: words/p06-248-03-04.png
#  extracting: words/g04-032-01-00.png
#  extracting: words/f04-057-08-04.png
#  extracting: words/h04-071-03-00.png
#  extracting: words/e04-114-07-02.png
#  extracting: words/c02-022-06-00.png
#  extracting: words/e02-100-00-04.png
#  extracting: words/g06-026a-00-10.png
#  extracting: words/j04-065-07-07.png
#  extracting: words/h07-003-02-03.png
#  extracting: words/d04-075-00-00.png
#  extracting: words/a05-113-06-03.png
#  extracting: words/e04-099-04-07.png
#  extracting: words/c06-106-06-04.png
#  extracting: words/b04-140-03-06.png
#  extracting: words/r02-109-07-08.png
#  extracting: words/c02-026-08-06.png
#  extracting: words/j04-076-03-06.png
#  extracting: words/j01-042-06-01.png
#  extracting: words/n04-139-05-04.png
#  extracting: words/h07-071a-05-05.png
#  extracting: words/e07-079-07-04.png
#  extracting: words/r03-053-03-06.png
#  extracting: words/b01-136-07-01.png
#  extracting: words/g06-018a-00-00.png
#  extracting: words/r06-057-08-03.png
#  extracting: words/m01-049-05-01.png
#  extracting: words/j01-066-07-03.png
#  extracting: words/p01-147-07-01.png
#  extracting: words/h04-007-03-01.png
#  extracting: words/n02-157-08-06.png
#  extracting: words/g07-014b-03-06.png
#  extracting: words/k02-067-06-01.png
#  extracting: words/d06-096-04-00.png
#  extracting: words/d06-104-05-03.png
#  extracting: words/g06-018e-04-02.png
#  extracting: words/e04-058-02-07.png
#  extracting: words/p02-144-08-07.png
#  extracting: words/c03-003e-03-02.png
#  extracting: words/g06-026h-01-01.png
#  extracting: words/e07-003-02-03.png
#  extracting: words/g04-060-04-11.png
#  extracting: words/c06-039-02-05.png
#  extracting: words/b04-010-07-03.png
#  extracting: words/m02-087-02-04.png
#  extracting: words/a01-026u-02-03.png
#  extracting: words/g06-018k-03-13.png
#  extracting: words/g06-037l-08-00.png
#  extracting: words/a04-089-04-04.png
#  extracting: words/b04-140-06-00.png
#  extracting: words/n04-107-02-06.png
#  extracting: words/a04-099-07-05.png
#  extracting: words/c01-066-04-00.png
#  extracting: words/c03-087a-03-03.png
#  extracting: words/k02-112-01-01.png
#  extracting: words/b01-073-03-08.png
#  extracting: words/g07-074a-05-03.png
#  extracting: words/m04-200-01-06.png
#  extracting: words/e06-033-09-07.png
#  extracting: words/c03-003f-02-00.png
#  extracting: words/p03-072-00-01.png
#  extracting: words/l01-187-04-02.png
#  extracting: words/e01-113-05-08.png
#  extracting: words/g04-026-02-01.png
#  extracting: words/c06-083-06-05.png
#  extracting: words/m01-110-09-01.png
#  extracting: words/g04-052-03-09.png
#  extracting: words/c06-083-05-04.png
#  extracting: words/f04-028-09-04.png
#  extracting: words/g06-037d-01-12.png
#  extracting: words/n04-114-07-07.png
#  extracting: words/d04-081-08-00.png
#  extracting: words/g06-026n-01-05.png
#  extracting: words/g01-043-01-04.png
#  extracting: words/n03-082-00-08.png
#  extracting: words/f04-087-03-06.png
#  extracting: words/n06-082-00-10.png
#  extracting: words/p03-185-04-04.png
#  extracting: words/k07-158-04-07.png
#  extracting: words/c02-078-02-02.png
#  extracting: words/b01-089-04-00.png
#   inflating: words/c03-000d-05-07.png
#  extracting: words/k02-029-00-03.png
#  extracting: words/k07-176-02-01.png
#  extracting: words/b06-093-09-02.png
#  extracting: words/c03-007f-08-03.png
#  extracting: words/a01-003u-02-01.png
#  extracting: words/m04-145-00-06.png
#  extracting: words/a03-080-08-00.png
#  extracting: words/g06-042g-00-12.png
#  extracting: words/d04-037-03-04.png
#  extracting: words/a02-027-03-03.png
#  extracting: words/n06-133-01-00.png
#  extracting: words/c03-007f-07-00.png
#  extracting: words/c03-084a-03-06.png
#  extracting: words/l07-181-07-05.png
#  extracting: words/n02-151-10-04.png
#  extracting: words/g06-011b-07-03.png
#  extracting: words/p03-121-05-02.png
#  extracting: words/m01-032-03-08.png
#  extracting: words/p03-103-04-04.png
#  extracting: words/c06-100-04-09.png
#  extracting: words/e06-033-00-00.png
#  extracting: words/k07-176-01-06.png
#  extracting: words/h02-035-02-00.png
#  extracting: words/a01-122-03-06.png
#  extracting: words/l04-179-06-04.png
#  extracting: words/n04-171-05-04.png
#  extracting: words/a03-017-04-00.png
#  extracting: words/a04-085-08-05.png
#  extracting: words/b04-047-02-04.png
#  extracting: words/c03-003e-07-05.png
#  extracting: words/m04-007-05-01.png
#  extracting: words/m06-042-02-04.png
#  extracting: words/m02-109-03-06.png
#  extracting: words/b04-066-04-01.png
#  extracting: words/a02-078-01-01.png
#  extracting: words/n04-218-05-05.png
#  extracting: words/a05-000-01-03.png
#  extracting: words/f02-030-04-07.png
#  extracting: words/m04-024-02-01.png
#  extracting: words/a06-090-00-07.png
#  extracting: words/e04-109-04-08.png
#  extracting: words/d04-032-10-03.png
#  extracting: words/g06-037i-04-05.png
#  extracting: words/c06-000-03-07.png
#  extracting: words/c01-009-04-02.png
#  extracting: words/c03-016b-01-08.png
#  extracting: words/g06-037i-03-00.png
#  extracting: words/a05-058-08-02.png
#  extracting: words/g01-031-06-04.png
#  extracting: words/b06-023-07-01.png
#  extracting: words/l01-187-09-05.png
#  extracting: words/n02-040-00-07.png
#  extracting: words/p01-147-00-03.png
#  extracting: words/g04-036-00-11.png
#  extracting: words/g06-050e-01-08.png
#  extracting: words/g04-104-03-10.png
#  extracting: words/a01-096u-06-03.png
#  extracting: words/l04-093-03-01.png
#  extracting: words/g07-079a-03-04.png
#  extracting: words/g06-042d-04-09.png
#  extracting: words/c04-139-01-14.png
#  extracting: words/e06-006-05-02.png
#  extracting: words/e01-025-06-04.png
#  extracting: words/e02-091-05-00.png
#  extracting: words/c03-007-06-00.png
#  extracting: words/k07-063a-06-07.png
#  extracting: words/k02-062-02-06.png
#  extracting: words/r02-127-03-06.png
#  extracting: words/b04-147-05-00.png
#  extracting: words/k03-157-03-04.png
#  extracting: words/h06-096-02-03.png
#  extracting: words/g06-047p-03-08.png
#  extracting: words/j06-034-07-00.png
#  extracting: words/k03-144-04-04.png
#  extracting: words/g06-042e-00-11.png
#  extracting: words/n01-000-06-01.png
#  extracting: words/l04-026-00-06.png
#  extracting: words/k07-152-01-01.png
#  extracting: words/n02-054-06-03.png
#  extracting: words/e01-035-00-02.png
#  extracting: words/k01-051-04-05.png
#  extracting: words/h04-055-03-04.png
#  extracting: words/f07-028a-01-04.png
#  extracting: words/g02-059-02-04.png
#  extracting: words/c03-003c-01-07.png
#  extracting: words/l01-199-02-06.png
#  extracting: words/k04-110-01-05.png
#  extracting: words/g06-018a-04-04.png
#  extracting: words/c03-084a-00-00.png
#  extracting: words/g06-011p-02-02.png
#  extracting: words/d01-049-07-05.png
#  extracting: words/g06-050a-07-06.png
#  extracting: words/n01-057-05-05.png
#  extracting: words/d01-060-08-01.png
#  extracting: words/g06-011p-06-05.png
#  extracting: words/a03-040-04-10.png
#  extracting: words/k04-110-05-02.png
#  extracting: words/g05-094-08-00.png
#  extracting: words/c03-087d-07-01.png
#  extracting: words/g06-047r-05-04.png
#  extracting: words/d04-062-02-05.png
#  extracting: words/d04-117-05-07.png
#  extracting: words/e07-079-03-02.png
#  extracting: words/g06-042h-04-06.png
#  extracting: words/k04-163-04-10.png
#  extracting: words/g01-008-06-07.png
#  extracting: words/h04-061-04-06.png
#  extracting: words/g04-095-01-06.png
#  extracting: words/k04-079-09-07.png
#  extracting: words/b01-044-06-00.png
#   inflating: words/g01-043-05-02.png
#  extracting: words/d03-112-03-01.png
#  extracting: words/h07-025-01-00.png
#  extracting: words/d06-025-05-04.png
#  extracting: words/l01-000-03-01.png
#  extracting: words/a05-009-00-00.png
#  extracting: words/r06-106-02-03.png
#  extracting: words/b04-096-01-08.png
#  extracting: words/l01-199-09-00.png
#  extracting: words/d06-027-02-01.png
#  extracting: words/g06-047c-03-00.png
#  extracting: words/b03-025-01-00.png
#  extracting: words/f04-011-08-09.png
#  extracting: words/g04-088-02-07.png
#  extracting: words/g07-030-01-01.png
#  extracting: words/m02-083-07-07.png
#  extracting: words/g06-018i-03-03.png
#  extracting: words/a01-020-04-07.png
#  extracting: words/c03-000d-04-04.png
#  extracting: words/e06-000-00-03.png
#  extracting: words/g06-037c-06-04.png
#  extracting: words/h02-028-06-02.png
#  extracting: words/f04-024-05-02.png
#  extracting: words/a01-072u-02-00.png
#  extracting: words/g06-045i-05-07.png
#  extracting: words/e06-010-07-05.png
#  extracting: words/k07-063a-02-02.png
#  extracting: words/a05-108-00-02.png
#  extracting: words/e06-030-08-02.png
#  extracting: words/a03-027-05-10.png
#  extracting: words/e07-112-04-00.png
#  extracting: words/r03-084-07-04.png
#  extracting: words/j04-098-08-00.png
#  extracting: words/g07-038-10-01.png
#  extracting: words/n01-052-00-07.png
#  extracting: words/b01-062-01-04.png
#  extracting: words/g07-050-02-05.png
#  extracting: words/k03-164-05-00.png
#  extracting: words/d06-020-02-04.png
#  extracting: words/g06-042p-03-05.png
#  extracting: words/a01-122-04-06.png
#  extracting: words/n02-114-00-06.png
#  extracting: words/c04-039-02-00.png
#  extracting: words/g06-037k-08-03.png
#  extracting: words/g04-043-05-10.png
#  extracting: words/l03-008-02-05.png
#  extracting: words/a01-003x-05-00.png
#  extracting: words/m03-095-07-01.png
#  extracting: words/c04-160-00-05.png
#  extracting: words/f02-040-01-03.png
#  extracting: words/g06-050k-02-05.png
#  extracting: words/b06-023-04-01.png
#  extracting: words/r02-054-03-11.png
#  extracting: words/k04-039-05-11.png
#  extracting: words/m04-030-03-14.png
#  extracting: words/a01-014x-05-05.png
#  extracting: words/p02-109-06-14.png
#  extracting: words/c03-003a-02-07.png
#  extracting: words/a02-020-03-00.png
#  extracting: words/p02-155-00-02.png
#  extracting: words/n04-100-05-06.png
#  extracting: words/c02-030-07-01.png
#  extracting: words/g06-018d-03-02.png
#  extracting: words/g06-026p-00-10.png
#  extracting: words/g07-026a-04-00.png
#  extracting: words/b05-058-02-11.png
#  extracting: words/g01-004-04-03.png
#  extracting: words/l04-136-03-03.png
#  extracting: words/g06-011i-06-06.png
#  extracting: words/c04-066-07-07.png
#  extracting: words/c04-160-05-07.png
#  extracting: words/n03-120-08-07.png
#  extracting: words/m01-060-05-07.png
#  extracting: words/c03-081b-04-04.png
#  extracting: words/h07-044a-07-05.png
#  extracting: words/a01-091u-05-06.png
#  extracting: words/c06-005-02-02.png
#  extracting: words/c03-081e-05-06.png
#  extracting: words/a04-019-00-03.png
#  extracting: words/l04-034-05-02.png
#  extracting: words/m03-114-05-07.png
#  extracting: words/p01-147-00-04.png
#  extracting: words/g06-045d-02-11.png
#  extracting: words/b06-036-04-04.png
#  extracting: words/c04-160-04-00.png
#  extracting: words/c03-087d-07-08.png
#  extracting: words/g06-045b-08-03.png
#  extracting: words/d01-080-04-07.png
#  extracting: words/r03-035-01-04.png
#  extracting: words/f07-024b-03-00.png
#  extracting: words/f07-046b-01-06.png
#  extracting: words/g06-045i-00-07.png
#  extracting: words/g06-026p-02-06.png
#  extracting: words/f07-006-01-02.png
#  extracting: words/c03-000c-06-04.png
#  extracting: words/d04-053-04-06.png
#  extracting: words/c04-066-02-07.png
#  extracting: words/b03-098-00-01.png
#  extracting: words/g06-011e-06-00.png
#  extracting: words/b01-000-06-01.png
#  extracting: words/c02-082-09-06.png
#  extracting: words/r03-002-05-03.png
#  extracting: words/g01-070-03-05.png
#  extracting: words/r03-035-07-11.png
#  extracting: words/g06-018d-07-03.png
#  extracting: words/a04-081-03-06.png
#  extracting: words/f07-000b-06-02.png
#  extracting: words/k03-138-01-06.png
#  extracting: words/e07-076-05-01.png
#  extracting: words/h07-028-08-00.png
#  extracting: words/g07-074a-05-04.png
#  extracting: words/g06-018g-01-03.png
#  extracting: words/d06-063-05-01.png
#  extracting: words/g06-031h-06-03.png
#  extracting: words/g06-047r-05-06.png
#  extracting: words/r06-000-02-04.png
#  extracting: words/p01-168-00-07.png
#  extracting: words/l03-008-07-00.png
#  extracting: words/k04-085-03-04.png
#  extracting: words/b01-004-06-04.png
#  extracting: words/d06-056-04-00.png
#  extracting: words/b04-047-02-12.png
#  extracting: words/j06-014-06-00.png
#  extracting: words/p03-135-03-08.png
#  extracting: words/r03-065-06-00.png
#  extracting: words/b01-118-08-00.png
#  extracting: words/l01-179-02-04.png
#  extracting: words/a01-102-10-03.png
#  extracting: words/l01-195-05-01.png
#  extracting: words/m02-052-05-02.png
#  extracting: words/b02-013-03-01.png
#  extracting: words/f04-007-05-04.png
#  extracting: words/e04-099-02-04.png
#  extracting: words/g06-018n-01-00.png
#  extracting: words/g06-011k-01-01.png
#  extracting: words/c03-021a-09-06.png
#  extracting: words/a03-063-09-06.png
#  extracting: words/d06-060-02-02.png
#  extracting: words/h07-063b-00-06.png
#  extracting: words/d06-096-01-04.png
#  extracting: words/j06-008-02-02.png
#  extracting: words/e02-094-09-06.png
#  extracting: words/l07-176-02-04.png
#  extracting: words/m01-121-01-03.png
#  extracting: words/d01-060-08-04.png
#  extracting: words/k04-017-08-09.png
#  extracting: words/g06-031a-04-07.png
#  extracting: words/a01-117-03-06.png
#  extracting: words/h07-033a-02-01.png
#  extracting: words/n02-062-05-04.png
#  extracting: words/g06-047p-01-07.png
#  extracting: words/d07-085-01-06.png
#  extracting: words/l07-131-01-02.png
#  extracting: words/g06-026f-04-03.png
#  extracting: words/p03-087-06-01.png
#  extracting: words/c03-000a-01-05.png
#  extracting: words/g06-047o-03-01.png
#  extracting: words/g06-018r-00-08.png
#  extracting: words/j04-115-03-01.png
#  extracting: words/g06-011e-08-06.png
#  extracting: words/g06-045k-04-00.png
#  extracting: words/n02-045-08-00.png
#  extracting: words/p03-096-02-07.png
#  extracting: words/c04-080-00-01.png
#  extracting: words/g01-070-07-08.png
#  extracting: words/c03-096e-06-08.png
#  extracting: words/n02-098-04-02.png
#  extracting: words/l04-066-06-09.png
#  extracting: words/b06-042-00-01.png
#  extracting: words/r02-117-04-09.png
#  extracting: words/g06-018d-00-05.png
#  extracting: words/l04-163-06-05.png
#  extracting: words/a06-124-03-08.png
#  extracting: words/h07-013-09-04.png
#  extracting: words/m01-149-06-11.png
#  extracting: words/m04-007-05-06.png
#  extracting: words/g04-022-00-01.png
#  extracting: words/g06-018e-00-05.png
#  extracting: words/a05-029-00-01.png
#  extracting: words/n06-074-06-05.png
#  extracting: words/l04-012-07-02.png
#  extracting: words/e01-059-01-05.png
#  extracting: words/b05-088-07-00.png
#  extracting: words/e04-004-04-06.png
# ...
#  extracting: words/r02-127-00-00.png
#  extracting: words/g07-022a-07-07.png
#  extracting: words/f04-016-03-03.png
#  extracting: words/b06-079-08-02.png
#  extracting: words/g07-084-05-07.png
#  extracting: words/f07-000b-02-06.png
#  extracting: words/k04-163-02-12.png
#  extracting: words/m04-078-06-03.png
#  extracting: words/l04-034-00-03.png
#  extracting: words/h07-044a-02-02.png
#  extracting: words/d06-027-06-03.png
#  extracting: words/g04-026-00-10.png
#  extracting: words/b04-147-03-05.png
#  extracting: words/p02-069-02-05.png
#  extracting: words/h02-019-04-05.png
#  extracting: words/m03-114-02-05.png
#  extracting: words/l07-176-04-05.png
#  extracting: words/a01-113u-05-01.png
#  extracting: words/e04-109-00-02.png
#  extracting: words/a01-072u-00-00.png
#  extracting: words/m01-100-03-01.png
#  extracting: words/g01-070-07-07.png
#  extracting: words/c03-021e-02-05.png
#  extracting: words/a01-014-09-03.png
#  extracting: words/b05-032-04-02.png
#  extracting: words/a02-008-04-03.png
#  extracting: words/g06-037j-00-10.png
#  extracting: words/j04-024-02-07.png
#  extracting: words/c03-007c-01-03.png
#  extracting: words/r03-035-04-03.png
#  extracting: words/c03-081b-00-04.png
#  extracting: words/k04-064-04-00.png
#  extracting: words/a03-047-01-08.png
#  extracting: words/h02-008-01-07.png
#  extracting: words/a02-120-10-00.png
#  extracting: words/m01-038-07-08.png
#  extracting: words/k04-005-05-02.png
#  extracting: words/k04-110-01-02.png
#  extracting: words/g07-038-08-00.png
#  extracting: words/e07-094-03-02.png
#  extracting: words/g06-050b-03-00.png
#  extracting: words/e02-025-03-03.png
#  extracting: words/g04-081-01-07.png
#  extracting: words/g06-042a-03-00.png
#  extracting: words/d06-037-05-01.png
#  extracting: words/c04-017-01-01.png
#  extracting: words/n04-044-08-02.png
#  extracting: words/a05-121-01-01.png
#  extracting: words/m04-019-07-01.png
#  extracting: words/g06-037d-04-01.png
#  extracting: words/p03-027-02-07.png
#  extracting: words/f04-032-07-00.png
#  extracting: words/d01-123-05-03.png
#  extracting: words/h01-007-03-07.png
#  extracting: words/c02-017-09-04.png
#  extracting: words/a01-030u-03-06.png
#  extracting: words/a01-007-01-05.png
#  extracting: words/f01-085-02-07.png
#  extracting: words/f03-191-05-03.png
#  extracting: words/a05-029-07-00.png
#  extracting: words/g06-042d-01-06.png
#  extracting: words/g07-034-01-10.png
#  extracting: words/a05-048-04-04.png
#  extracting: words/g06-026l-00-06.png
#  extracting: words/a05-073-04-01.png
#  extracting: words/l03-008-06-03.png
#  extracting: words/m04-209-04-00.png
#  extracting: words/h06-003-08-07.png
#  extracting: words/l07-187-02-02.png
#  extracting: words/c03-081e-03-05.png
#  extracting: words/a02-057-07-04.png
#  extracting: words/j04-012-00-01.png
#  extracting: words/k04-064-05-06.png
#  extracting: words/a05-080-02-02.png
#  extracting: words/c03-007f-00-00.png
#  extracting: words/h06-000-00-05.png
#  extracting: words/g06-047r-02-09.png
#  extracting: words/m01-022-03-09.png
#  extracting: words/g01-070-07-04.png
#  extracting: words/g03-032-01-06.png
#  extracting: words/g03-052-05-05.png
#  extracting: words/p03-069-02-01.png
#  extracting: words/k04-005-05-00.png
#  extracting: words/c03-081b-03-08.png
#  extracting: words/e07-079-01-01.png
#  extracting: words/k02-067-07-04.png
#  extracting: words/d01-016-02-14.png
#  extracting: words/b01-113-07-00.png
#  extracting: words/a02-078-00-07.png
#  extracting: words/c01-009-04-03.png
#  extracting: words/g06-037b-00-06.png
#  extracting: words/g06-050d-04-07.png
#  extracting: words/g07-071a-00-01.png
#  extracting: words/f07-096-05-01.png
#  extracting: words/l07-065-04-12.png
#  extracting: words/a06-004-04-03.png
#  extracting: words/g05-094-00-01.png
#  extracting: words/n03-097-03-03.png
#  extracting: words/b05-071-00-07.png
#  extracting: words/l03-000-00-01.png
#  extracting: words/g05-087-05-04.png
#  extracting: words/n03-126-01-06.png
#  extracting: words/f02-020-01-05.png
#  extracting: words/h01-014-03-02.png
#  extracting: words/a05-094-01-07.png
#  extracting: words/b02-013-07-05.png
#  extracting: words/n02-157-02-05.png
#  extracting: words/m03-020-03-08.png
#  extracting: words/b01-089-05-01.png
#  extracting: words/c06-138-03-02.png
#  extracting: words/g06-042a-00-07.png
#  extracting: words/l01-007-00-03.png
#  extracting: words/f01-066-05-04.png
#  extracting: words/d04-075-00-04.png
#  extracting: words/g06-050m-09-02.png
#  extracting: words/l01-133-07-01.png
#  extracting: words/b06-056-07-02.png
#  extracting: words/m04-180-06-06.png
#  extracting: words/d07-085-03-06.png
#  extracting: words/a06-110-03-00.png
#  extracting: words/a02-082-02-03.png
#  extracting: words/h07-017-07-05.png
#  extracting: words/b06-097-00-03.png
#  extracting: words/h07-075-03-00.png
#  extracting: words/e06-046-02-02.png
#  extracting: words/a03-047-07-06.png
#  extracting: words/g06-042o-07-02.png
#  extracting: words/n06-123-08-01.png
#  extracting: words/p02-127-03-05.png
#  extracting: words/r03-090-04-03.png
#  extracting: words/l04-000-03-07.png
#  extracting: words/c02-007-02-07.png
#  extracting: words/e04-004-03-01.png
#  extracting: words/l01-095-03-03.png
#  extracting: words/a01-030u-08-00.png
#  extracting: words/f07-013-10-00.png
#  extracting: words/f02-036-00-06.png
#  extracting: words/g05-098-03-07.png
#  extracting: words/l01-111-07-02.png
#  extracting: words/d06-056-05-09.png
#  extracting: words/h04-071-04-03.png
#  extracting: words/h07-071-02-04.png
#  extracting: words/k04-115-02-02.png
#  extracting: words/j01-070-06-04.png
#  extracting: words/j07-009-05-02.png
#  extracting: words/a01-003-04-05.png
#  extracting: words/n04-009-04-03.png
#  extracting: words/r03-056-02-08.png
#  extracting: words/e06-041-00-00.png
#  extracting: words/g06-031o-00-03.png
#  extracting: words/n02-082a-05-08.png
#  extracting: words/h07-037a-01-02.png
#  extracting: words/n06-074-04-03.png
#  extracting: words/m02-052-03-05.png
#  extracting: words/f01-053-02-03.png
#  extracting: words/k07-158-05-05.png
#  extracting: words/l01-007-01-00.png
#  extracting: words/p02-090-04-01.png
#  extracting: words/a03-027-04-07.png
#  extracting: words/m04-131-03-06.png
#  extracting: words/h02-004-03-08.png
#  extracting: words/g06-011o-04-09.png
#  extracting: words/g06-037h-09-01.png
#  extracting: words/a04-066-05-01.png
#  extracting: words/l04-087-04-02.png
#  extracting: words/d04-075-05-04.png
#  extracting: words/g06-031h-04-01.png
#  extracting: words/b05-038-00-03.png
#  extracting: words/g06-047m-00-02.png
#  extracting: words/n04-213-04-06.png
#  extracting: words/e02-018-04-00.png
#  extracting: words/b06-071-02-01.png
#  extracting: words/n02-004-08-04.png
#  extracting: words/m02-059-02-04.png
#  extracting: words/l01-143-01-03.png
#  extracting: words/e01-092-06-03.png
#  extracting: words/b04-154-06-04.png
#  extracting: words/r06-018-02-02.png
#  extracting: words/p02-105-00-10.png
#  extracting: words/m01-125-04-06.png
#  extracting: words/h07-040b-10-03.png
#  extracting: words/e04-086-04-07.png
#  extracting: words/n04-022-02-04.png
#  extracting: words/c03-016b-01-05.png
#  extracting: words/l03-008-06-09.png
#  extracting: words/c01-066-05-00.png
#  extracting: words/h07-007-01-06.png
#  extracting: words/f01-085-05-01.png
#  extracting: words/b01-122-08-04.png
#  extracting: words/a05-073-00-03.png
#  extracting: words/g06-042r-01-05.png
#  extracting: words/b05-045-00-06.png
#  extracting: words/g07-026b-05-07.png
#  extracting: words/g02-059-00-01.png
#  extracting: words/f04-087-00-07.png
#  extracting: words/g01-070-06-02.png
#  extracting: words/b01-073-03-05.png
#  extracting: words/f04-024-05-11.png
#  extracting: words/p01-147-07-03.png
#  extracting: words/p03-087-07-04.png
#  extracting: words/b03-092-02-06.png
#  extracting: words/a05-084-00-07.png
#  extracting: words/d07-089-05-07.png
#  extracting: words/m01-022-02-01.png
#  extracting: words/m01-026-07-01.png
#  extracting: words/b04-004-07-03.png
#  extracting: words/g07-050-02-06.png
#  extracting: words/n06-186-04-03.png
#  extracting: words/a03-011-03-06.png
#  extracting: words/c04-156-06-04.png
#  extracting: words/c02-049-05-01.png
#  extracting: words/g06-031o-08-03.png
#  extracting: words/m04-012-03-03.png
#  extracting: words/l01-119-00-04.png
#  extracting: words/n04-195-02-00.png
#  extracting: words/g07-003b-03-07.png
#  extracting: words/m03-013-05-09.png
#  extracting: words/a06-110-06-01.png
#  extracting: words/k07-141-05-06.png
#  extracting: words/j04-035-05-00.png
#  extracting: words/m01-032-05-02.png
#  extracting: words/r02-060-06-01.png
#  extracting: words/g06-031j-06-03.png
#  extracting: words/m02-102-00-02.png
#  extracting: words/d04-089-07-06.png
#   inflating: words/m04-131-08-01.png
#  extracting: words/g07-022b-03-03.png
#  extracting: words/j04-053-04-05.png
#  extracting: words/f04-011-04-07.png
#  extracting: words/a06-000-01-00.png
#  extracting: words/m01-012-08-04.png
#  extracting: words/a04-023-02-02.png
#  extracting: words/c03-081c-00-03.png
#  extracting: words/p03-029-09-02.png
#  extracting: words/n06-163-04-10.png
#  extracting: words/a05-113-05-03.png
#  extracting: words/a03-063-09-01.png
#  extracting: words/r02-070-04-02.png
#  extracting: words/a02-106-09-05.png
#  extracting: words/n01-052-08-06.png
#  extracting: words/p02-081-01-06.png
#  extracting: words/g03-052-08-07.png
#  extracting: words/c04-116-03-04.png
#  extracting: words/r02-038-04-00.png
#  extracting: words/f02-030-06-03.png
#  extracting: words/c03-007f-05-07.png
#  extracting: words/e04-043-01-07.png
#  extracting: words/g02-065-01-05.png
#  extracting: words/d07-093-08-04.png
#  extracting: words/a01-053-07-05.png
#  extracting: words/b04-116-04-05.png
#  extracting: words/g06-031p-05-01.png
#  extracting: words/k07-067a-04-05.png
#  extracting: words/a06-095-00-06.png
#  extracting: words/a01-091-00-01.png
#  extracting: words/r02-127-01-08.png
#  extracting: words/l04-000-03-05.png
#  extracting: words/h07-063b-01-07.png
#  extracting: words/g06-101-01-07.png
#  extracting: words/r02-131-04-12.png
#  extracting: words/h07-040b-08-01.png
#  extracting: words/k04-061-00-03.png
#  extracting: words/j04-111-03-01.png
#  extracting: words/g06-050a-01-09.png
#  extracting: words/m04-152-01-14.png
#  extracting: words/p03-121-01-05.png
#  extracting: words/m01-079-02-06.png
#  extracting: words/r02-000-00-07.png
#  extracting: words/h07-071-01-04.png
#   inflating: words/a01-014x-07-07.png
#  extracting: words/p06-242-07-00.png
#  extracting: words/h07-071-01-01.png
#  extracting: words/b01-094-07-01.png
#  extracting: words/b01-127-06-03.png
#  extracting: words/f03-182-01-09.png
#  extracting: words/c02-026-00-00.png
#  extracting: words/j07-012-03-03.png
#  extracting: words/g06-047p-01-02.png
#  extracting: words/n03-064-03-08.png
#  extracting: words/g06-031r-05-01.png
#  extracting: words/c02-000-00-02.png
#  extracting: words/m06-106-03-10.png
#  extracting: words/g01-037-04-02.png
#  extracting: words/a01-122u-04-05.png
#  extracting: words/r03-065-00-08.png
#  extracting: words/e06-030-02-06.png
#  extracting: words/g06-050j-01-02.png
#  extracting: words/b01-079-10-07.png
#  extracting: words/b04-004-00-03.png
#  extracting: words/b04-054-01-00.png
#  extracting: words/r03-090-05-00.png
#  extracting: words/m03-095-00-02.png
#  extracting: words/g01-034-00-05.png
#  extracting: words/c02-007-02-06.png
#  extracting: words/c02-012-03-04.png
#  extracting: words/b06-059-01-04.png
#  extracting: words/k04-050-02-11.png
#  extracting: words/h06-096-03-04.png
#  extracting: words/k02-067-04-07.png
#  extracting: words/g04-007-03-00.png
#  extracting: words/a05-080-05-03.png
#  extracting: words/l04-102-00-03.png
#  extracting: words/f07-002-01-05.png
#  extracting: words/c04-139-01-07.png
#  extracting: words/k02-102-01-06.png
#  extracting: words/r06-111-03-01.png
#  extracting: words/e01-119-07-06.png
#  extracting: words/m01-115-05-01.png
#  extracting: words/c03-016c-04-03.png
#  extracting: words/g07-000a-08-06.png
#  extracting: words/a01-072x-01-07.png
#  extracting: words/a04-103-05-02.png
#  extracting: words/l04-071-07-08.png
#  extracting: words/f01-053-07-03.png
#  extracting: words/b02-045-08-02.png
#  extracting: words/l04-118-07-04.png
#  extracting: words/h01-024-05-04.png
#  extracting: words/f07-046b-00-00.png
#  extracting: words/r02-013-00-05.png
#  extracting: words/g06-018a-07-07.png
#  extracting: words/a01-030x-01-08.png
#  extracting: words/g06-045j-03-03.png
#  extracting: words/j06-034-02-01.png
#  extracting: words/f07-084b-06-05.png
#  extracting: words/g04-022-01-06.png
#  extracting: words/a02-037-08-09.png
#  extracting: words/b04-066-02-04.png
#  extracting: words/g06-026c-04-03.png
#  extracting: words/f07-016-00-03.png
#  extracting: words/d04-050-04-06.png
#  extracting: words/c03-000b-00-08.png
#  extracting: words/p03-080-03-00.png
#  extracting: words/m01-110-06-09.png
#  extracting: words/n06-074-06-02.png
#  extracting: words/d07-085-00-09.png
#  extracting: words/a03-023-09-02.png
#  extracting: words/g07-044-02-05.png
#  extracting: words/d01-085-05-06.png
#  extracting: words/k07-125-04-08.png
#  extracting: words/g06-047a-02-10.png
#  extracting: words/b04-075-04-06.png
#  extracting: words/f04-083-05-09.png
#  extracting: words/m02-090-03-06.png
#  extracting: words/b04-010-01-06.png
#  extracting: words/h07-040-07-02.png
#  extracting: words/d06-086-01-00.png
#  extracting: words/b04-128-05-01.png
#  extracting: words/l04-066-06-07.png
#  extracting: words/c04-105-02-06.png
#  extracting: words/d04-121-00-00.png
#  extracting: words/l01-187-03-02.png
#  extracting: words/l07-080-03-03.png
#  extracting: words/a03-063-05-00.png
#  extracting: words/h07-040b-01-05.png
#  extracting: words/a02-120-07-03.png
#  extracting: words/f04-093-07-00.png
#  extracting: words/c03-096e-03-03.png
#  extracting: words/a05-053-02-00.png
#  extracting: words/e02-025-05-03.png
#  extracting: words/k07-176-01-01.png
#  extracting: words/l01-187-05-02.png
#  extracting: words/g06-037j-04-08.png
#  extracting: words/e01-032-09-01.png
#  extracting: words/a01-087-08-01.png
#  extracting: words/a03-023-06-01.png
#  extracting: words/c03-096b-04-07.png
#  extracting: words/a06-064-02-02.png
#  extracting: words/b04-060-00-06.png
#  extracting: words/b01-033-00-02.png
#  extracting: words/a05-099-00-03.png
#  extracting: words/k07-166-07-01.png
#  extracting: words/g06-031a-01-08.png
#  extracting: words/a03-037-01-01.png
#  extracting: words/r02-006-00-01.png
#  extracting: words/r06-057-02-06.png
#  extracting: words/a06-075-06-07.png
#  extracting: words/n06-128-07-03.png
#  extracting: words/g06-026i-02-11.png
#  extracting: words/c02-089-01-02.png
#  extracting: words/m01-121-03-06.png
#  extracting: words/g06-050l-05-02.png
#  extracting: words/f07-076a-00-06.png
#  extracting: words/r06-062-04-01.png
#  extracting: words/b04-040-04-05.png
#  extracting: words/g07-079a-09-06.png
#  extracting: words/c03-087a-03-06.png
#  extracting: words/n02-157-00-00.png
#  extracting: words/g06-045f-01-06.png
#  extracting: words/a04-039-05-02.png
#  extracting: words/j04-076-04-01.png
#  extracting: words/c04-013-03-02.png
#  extracting: words/g07-007b-03-03.png
#  extracting: words/g06-011j-02-01.png
#  extracting: words/a05-044-03-03.png
#  extracting: words/d04-050-01-09.png
#  extracting: words/a06-057-02-06.png
#  extracting: words/g06-011a-09-05.png
#  extracting: words/g06-042p-00-04.png
#  extracting: words/g04-072-01-10.png
#  extracting: words/f04-079-01-00.png
#  extracting: words/a01-011-06-02.png
#  extracting: words/n02-004-06-09.png
#  extracting: words/a02-024-07-03.png
#  extracting: words/h07-071a-01-07.png
#  extracting: words/m06-106-08-05.png
#  extracting: words/k04-106-04-08.png
#  extracting: words/r06-090-03-07.png
#  extracting: words/g07-074a-08-05.png

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import os
import numpy as np

# %% [markdown]
# ## Reading words.txt and random sampling 15000 words that does not have errors

# %%
with open('/content/drive/MyDrive/TCSion/words.txt') as f:
    contents = f.readlines()
f.close()

# %%
def clean(text):
    temp = text.rstrip("\n").split(' ')
    return temp[0] + ' ' + " ".join(temp[8:])

# %%
img_files = [f.split('.png')[0] for f in os.listdir('words')]
file_list = [clean(f) for f in contents[18:] if f.split(' ')[1] == 'ok']
file_list = [itm for itm in file_list if itm.split(' ')[0] in img_files]

# %%
len(img_files)
# Out:
# 90000

# %%
file_names = [itm.split(' ')[0] for itm in file_list]
labels = [' '.join(itm.split(' ')[1:]) for itm in file_list]

# %%
len(labels)
# Out:
# 90000

# %%
char_set = set()
for word in labels:
    for char in word:
        char_set.add(char)

char_set.remove(' ')
char_list = sorted(list(char_set))

# %%
for word in labels:
    if word.count(' ') > 0:
        print(word)
# Out:
# M P
# 0M Ps
# 0M P
# M Ps
# M Ps
# M Ps
# M Ps
# 0M Ps
# M Ps
# M Ps
# M Ps
# M Ps
# M Ps
# B B C
# T V
# B B C
# B B C
# I T V
# T V
# C O
# B B C's
# T V
# n log n

# %%
max_label_len = 0

def encode_to_labels(txt):
    # encoding each output word into digits
    dig_lst = []
    for index, chara in enumerate(txt):
        dig_lst.append(char_list.index(chara))
    return dig_lst

def process_image(img):
    """
    Converts image to shape (32, 128, 1) & normalize
    """
    w, h = img.shape

    # Aspect Ratio Calculation
    new_w = 32
    new_h = int(h * (new_w / w))
    img = cv2.resize(img, (new_h, new_w))
    w, h = img.shape

    img = img.astype('float32')

    # Converts each to (32, 128, 1)
    if w < 32:
        add_zeros = np.full((32-w, h), 255)
        img = np.concatenate((img, add_zeros))
        w, h = img.shape

    if h < 128:
        add_zeros = np.full((w, 128-h), 255)
        img = np.concatenate((img, add_zeros), axis=1)
        w, h = img.shape

    if h > 128 or w > 32:
        dim = (128,32)
        img = cv2.resize(img, dim)

    img = cv2.subtract(255, img)
    img = np.expand_dims(img, axis=2)

    # Normalize
    img = img / 255
    return img

# %%
max_label_len = 0
all_images = []
all_labels = []
all_input_length = []
label_length = []
original_text = []

for line in file_list:
    splits = line.split(' ')
    file_name = splits[0]
    word = ' '.join(splits[1:])
    img = cv2.imread('words/{}.png'.format(file_name), cv2.IMREAD_GRAYSCALE)
    #print(img)
    try:
        img = process_image(img)
        label = encode_to_labels(word)
        #print(label)
    except:
        print(f"[{word}]")
        continue
    all_images.append(img)
    all_labels.append(label)
    all_input_length.append(31)
    label_length.append(len(word))
    original_text.append(word)

    if len(word) > max_label_len:
        max_label_len = len(word)
# Out:
# [M P]
# [0M Ps]
# [0M P]
# [M Ps]
# [M Ps]
# [M Ps]
# [M Ps]
# [0M Ps]
# [M Ps]
# [M Ps]
# [M Ps]
# [Powell]
# [M Ps]
# [M Ps]
# [B B C]
# [T V]
# [B B C]
# [B B C]
# [I T V]
# [T V]
# [C O]
# [B B C's]
# [T V]
# [n log n]
# [more]

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
padded_labels = pad_sequences(all_labels, maxlen=max_label_len, padding='post')
padded_labels = np.asarray(padded_labels)

# %%
train_size = 0.85

split_index = int(len(all_images) * 0.85)
train_images = np.array(all_images[:split_index])
valid_images = np.array(all_images[split_index:])

train_padded_label = np.array(padded_labels[:split_index])
valid_padded_label = np.array(padded_labels[split_index:])

train_input_length = np.array(all_input_length[:split_index])
valid_input_length = np.array(all_input_length[split_index:])

train_label_length = np.array(label_length[:split_index])
valid_label_length = np.array(label_length[split_index:])

train_original_text = np.array(original_text[:split_index])
valid_original_text = np.array(original_text[split_index:])

# %%
train_padded_label.shape, valid_padded_label.shape, max_label_len
# Out:
# ((76478, 21), (13497, 21), 21)

# %%
train_images.shape, valid_images.shape, train_input_length.shape, valid_input_length.shape, train_label_length.shape, valid_label_length.shape, train_original_text.shape, valid_original_text.shape
# Out:
# ((76478, 32, 128, 1),
#  (13497, 32, 128, 1),
#  (76478,),
#  (13497,),
#  (76478,),
#  (13497,),
#  (76478,),
#  (13497,))

# %% [markdown]
# ###Model building

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Bidirectional, LSTM, MaxPool2D, Input, Lambda
#from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
inputs = Input(shape=(32,128,1))

# convolution layer with kernel size (3,3)
conv_1 = Conv2D(64, (3,3), activation = 'relu', padding='same')(inputs)
# poolig layer with kernel size (2,2)
pool_1 = MaxPool2D(pool_size=(2, 2), strides=2)(conv_1)

conv_2 = Conv2D(128, (3,3), activation = 'relu', padding='same')(pool_1)
pool_2 = MaxPool2D(pool_size=(2, 2), strides=2)(conv_2)

conv_3 = Conv2D(256, (3,3), activation = 'relu', padding='same')(pool_2)

conv_4 = Conv2D(256, (3,3), activation = 'relu', padding='same')(conv_3)

# poolig layer with kernel size (2,1)
pool_4 = MaxPool2D(pool_size=(2, 1))(conv_4)

conv_5 = Conv2D(512, (3,3), activation = 'relu', padding='same')(pool_4)

# Batch normalization layer
batch_norm_5 = BatchNormalization()(conv_5)

conv_6 = Conv2D(512, (3,3), activation = 'relu', padding='same')(batch_norm_5)
batch_norm_6 = BatchNormalization()(conv_6)
pool_6 = MaxPool2D(pool_size=(2, 1))(batch_norm_6)

conv_7 = Conv2D(512, (2,2), activation = 'relu')(pool_6)

squeezed = Lambda(lambda x: K.squeeze(x, 1))(conv_7)

# bidirectional LSTM layers with units=256
blstm_1 = Bidirectional(LSTM(256, return_sequences=True, dropout = 0.2))(squeezed)
blstm_2 = Bidirectional(LSTM(256, return_sequences=True, dropout = 0.2))(blstm_1)

outputs = Dense(len(char_list) + 1, activation = 'softmax')(blstm_2)

# model to be used at test time
act_model = Model(inputs, outputs)

act_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 128, 1)]      0
#
#  conv2d (Conv2D)             (None, 32, 128, 64)       640
#
#  max_pooling2d (MaxPooling2  (None, 16, 64, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 16, 64, 128)       73856
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 32, 128)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 32, 256)        295168
#
#  conv2d_3 (Conv2D)           (None, 8, 32, 256)        590080
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 32, 256)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 32, 512)        1180160
#
#  batch_normalization (Batch  (None, 4, 32, 512)        2048
#  Normalization)
#
#  conv2d_5 (Conv2D)           (None, 4, 32, 512)        2359808
#
#  batch_normalization_1 (Bat  (None, 4, 32, 512)        2048
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 2, 32, 512)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 1, 31, 512)        1049088
#
#  lambda (Lambda)             (None, 31, 512)           0
#
#  bidirectional (Bidirection  (None, 31, 512)           1574912
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 31, 512)           1574912
#  onal)
#
#  dense (Dense)               (None, 31, 79)            40527
#
# =================================================================
# Total params: 8743247 (33.35 MB)
# Trainable params: 8741199 (33.35 MB)
# Non-trainable params: 2048 (8.00 KB)
# _________________________________________________________________

# %%
the_labels = Input(name='the_labels', shape=[max_label_len], dtype='float32')
input_length = Input(name='input_length', shape=[1], dtype='int8')
label_length = Input(name='label_length', shape=[1], dtype='int8')

def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args

    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

loss_out = Lambda(ctc_lambda_func, output_shape=(1,), name='ctc')([outputs, the_labels, input_length, label_length])

#model to be used at training time
model = Model(inputs=[inputs, the_labels, input_length, label_length], outputs=loss_out)

# %%
batch_size = 8
epochs = 35
e = str(epochs)
optimizer = 'sgd'

# %%
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer=optimizer, metrics=['accuracy'])

filepath="weights.hdf5"

checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_accuracy', verbose=2, save_best_only=True, mode='auto')
callbacks_list = [checkpoint]

# %%
with open('model.json', 'w') as f:
    f.write(model.to_json())
f.close()

# %%
history = model.fit(x=[train_images, train_padded_label, train_input_length, train_label_length],
                    y=np.zeros(len(train_images)),
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=([valid_images, valid_padded_label, valid_input_length, valid_label_length], [np.zeros(len(valid_images))]),
                    verbose=2,
                    callbacks=callbacks_list)

# %%
# !cp "weights.hdf5" "/content/drive/MyDrive/TCSion/weights.hdf5"
# !cp "model.json" "/content/drive/MyDrive/TCSion//model.json"

act_model.load_weights(filepath)
act_model.save("full_model.h5")
# !cp "full_model.h5" "/content/drive/MyDrive/TCSion/full_model.h5"

# %% [markdown]
# ###Testing

# %%
act_model.load_weights(filepath)

# predict outputs on validation images
prediction = act_model.predict(valid_images)

# %%
import matplotlib.pyplot as plt

# %%
from keras.models import load_model

saved_model = load_model("full_model.h5")

# %%
def predict_image(index):
    pred = saved_model.predict(np.expand_dims(valid_images[index], axis=0))
    out = K.get_value(K.ctc_decode(pred, input_length=np.ones(pred.shape[0]) * pred.shape[1], greedy=True)[0][0])
    letters = ''
    for x in out[0]:
        if int(x) != -1:
            letters += char_list[int(x)]
    return letters, valid_original_text[index]

# %%
for i in range(10):
    predicted_text, original_text = predict_image(i)
    plt.imshow(valid_images[i], cmap=plt.cm.gray)
    plt.show()
    print(predicted_text, original_text)

# %%
plt.imshow(valid_images[0], cmap=plt.cm.gray)

# %%
pred = saved_model.predict(np.expand_dims(valid_images[0], axis=0))
out = K.get_value(K.ctc_decode(pred, input_length=np.ones(pred.shape[0]) * pred.shape[1], greedy=True)[0][0])
out
